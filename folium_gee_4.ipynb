# %% [markdown]
# # Add a draggable legend to folium maps

# %%
! pip install geemap
import folium
import geopandas
import pandas as pd
import json
import random
import requests
import os
from branca.colormap import linear
import ee
# Out:
# Requirement already satisfied: geemap in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (0.8.16)
# Requirement already satisfied: pyshp>=2.1.3 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from geemap) (2.1.3)
# Requirement already satisfied: ipytree in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from geemap) (0.2.1)
# Requirement already satisfied: colour in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from geemap) (0.1.5)
# Requirement already satisfied: voila in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from geemap) (0.2.10)
# Requirement already satisfied: pywin32 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from geemap) (300)
# Requirement already satisfied: folium>=0.11.0 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from geemap) (0.12.1)
# Requirement already satisfied: ffmpeg-python in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from geemap) (0.2.0)
# Requirement already satisfied: pillow in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from geemap) (8.2.0)
# Requirement already satisfied: geeadd>=0.5.1 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from geemap) (0.5.5)
# Requirement already satisfied: ipynb-py-convert in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from geemap) (0.4.6)
# Requirement already satisfied: ipyfilechooser in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from geemap) (0.4.3)
# Requirement already satisfied: pycrs in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from geemap) (1.0.2)
# Requirement already satisfied: bqplot in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from geemap) (0.12.29)
# Requirement already satisfied: python-box in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from geemap) (5.3.0)
# Requirement already satisfied: geocoder in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from geemap) (1.38.1)
# Requirement already satisfied: pandas in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from geemap) (1.2.4)
# Requirement already satisfied: ipyleaflet<=0.13.3 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from geemap) (0.13.3)
# Requirement already satisfied: mss in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from geemap) (6.1.0)
# Requirement already satisfied: whiteboxgui in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from geemap) (0.3.0)
# Requirement already satisfied: matplotlib in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from geemap) (3.4.2)
# Requirement already satisfied: click in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from geemap) (7.1.2)
# Requirement already satisfied: numpy in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from geemap) (1.20.3)
# Requirement already satisfied: googledrivedownloader in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from geemap) (0.4)
# Requirement already satisfied: earthengine-api>=0.1.230 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from geemap) (0.1.270)
# Requirement already satisfied: ipyevents in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from geemap) (0.8.2)
# Requirement already satisfied: sankee in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from geemap) (0.0.5)
# Requirement already satisfied: httplib2shim in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from earthengine-api>=0.1.230->geemap) (0.0.3)
# Requirement already satisfied: google-cloud-storage in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from earthengine-api>=0.1.230->geemap) (1.38.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from earthengine-api>=0.1.230->geemap) (0.19.1)
# Requirement already satisfied: future in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from earthengine-api>=0.1.230->geemap) (0.18.2)
# Requirement already satisfied: six in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from earthengine-api>=0.1.230->geemap) (1.16.0)
# Requirement already satisfied: google-auth>=1.4.1 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from earthengine-api>=0.1.230->geemap) (1.31.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from earthengine-api>=0.1.230->geemap) (0.1.0)
# Requirement already satisfied: google-api-python-client<2,>=1.12.1 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from earthengine-api>=0.1.230->geemap) (1.12.8)
# Requirement already satisfied: requests in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from folium>=0.11.0->geemap) (2.25.1)
# Requirement already satisfied: branca>=0.3.0 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from folium>=0.11.0->geemap) (0.4.2)
# Requirement already satisfied: jinja2>=2.9 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from folium>=0.11.0->geemap) (3.0.1)
# Requirement already satisfied: logzero>=1.5.0 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from geeadd>=0.5.1->geemap) (1.7.0)
# Requirement already satisfied: beautifulsoup4>=4.9.0 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from geeadd>=0.5.1->geemap) (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from beautifulsoup4>=4.9.0->geeadd>=0.5.1->geemap) (2.2.1)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.230->geemap) (3.0.1)
# Requirement already satisfied: google-api-core<2dev,>=1.21.0 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.230->geemap) (1.30.0)
# Requirement already satisfied: packaging>=14.3 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.230->geemap) (20.9)
# Requirement already satisfied: setuptools>=40.3.0 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.230->geemap) (49.6.0.post20210108)
# Requirement already satisfied: pytz in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.230->geemap) (2021.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.230->geemap) (1.53.0)
# Requirement already satisfied: protobuf>=3.12.0 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.230->geemap) (3.17.3)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.230->geemap) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.230->geemap) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.230->geemap) (0.2.8)
# Requirement already satisfied: pyparsing<3,>=2.4.2 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from httplib2<1dev,>=0.9.2->earthengine-api>=0.1.230->geemap) (2.4.7)
# Requirement already satisfied: ipywidgets<8,>=7.5.0 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from ipyleaflet<=0.13.3->geemap) (7.6.3)
# Requirement already satisfied: traittypes<3,>=0.2.1 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from ipyleaflet<=0.13.3->geemap) (0.2.1)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (5.0.5)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (3.5.1)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (7.24.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (1.0.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (5.5.5)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (5.1.3)
# Requirement already satisfied: tornado>=4.2 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (6.1)
# Requirement already satisfied: jupyter-client in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (6.1.12)
# Requirement already satisfied: matplotlib-inline in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (0.1.2)
# Requirement already satisfied: jedi>=0.16 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (0.18.0)
# Requirement already satisfied: decorator in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (5.0.9)
# Requirement already satisfied: pickleshare in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (0.7.5)
# Requirement already satisfied: pygments in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (2.9.0)
# Requirement already satisfied: colorama in c:\users\34639\appdata\roaming\python\python39\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (0.4.4)
# Requirement already satisfied: backcall in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (3.0.18)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (0.8.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from jinja2>=2.9->folium>=0.11.0->geemap) (2.0.1)
# Requirement already satisfied: jupyter-core in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (4.7.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (3.2.0)
# Requirement already satisfied: ipython-genutils in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (0.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (21.2.0)
# Requirement already satisfied: wcwidth in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (0.2.5)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api>=0.1.230->geemap) (0.4.8)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from requests->folium>=0.11.0->geemap) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from requests->folium>=0.11.0->geemap) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from requests->folium>=0.11.0->geemap) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from requests->folium>=0.11.0->geemap) (2021.5.30)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (6.4.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (0.10.1)
# Requirement already satisfied: prometheus-client in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (0.11.0)
# Requirement already satisfied: nbconvert in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (6.0.7)
# Requirement already satisfied: argon2-cffi in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (20.1.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (22.1.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (1.5.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (2.8.1)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (1.1.1)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (1.14.5)
# Requirement already satisfied: pycparser in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (2.20)
# Requirement already satisfied: ratelim in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from geocoder->geemap) (0.1.6)
# Requirement already satisfied: google-cloud-core<2.0dev,>=1.4.1 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from google-cloud-storage->earthengine-api>=0.1.230->geemap) (1.7.0)
# Requirement already satisfied: google-resumable-media<2.0dev,>=1.2.0 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from google-cloud-storage->earthengine-api>=0.1.230->geemap) (1.3.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from google-resumable-media<2.0dev,>=1.2.0->google-cloud-storage->earthengine-api>=0.1.230->geemap) (1.1.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from matplotlib->geemap) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from matplotlib->geemap) (1.3.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (0.5.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (0.8.4)
# Requirement already satisfied: bleach in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (3.3.0)
# Requirement already satisfied: testpath in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (0.5.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (0.1.2)
# Requirement already satisfied: defusedxml in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (1.4.2)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (0.3)
# Requirement already satisfied: nest-asyncio in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (1.5.1)
# Requirement already satisfied: async-generator in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (1.10)
# Requirement already satisfied: webencodings in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet<=0.13.3->geemap) (0.5.1)
# Requirement already satisfied: plotly in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from sankee->geemap) (4.14.3)
# Requirement already satisfied: retrying>=1.3.3 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from plotly->sankee->geemap) (1.3.3)
# Requirement already satisfied: jupyter-server<2.0.0,>=0.3.0 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from voila->geemap) (1.8.0)
# Requirement already satisfied: websocket-client in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from jupyter-server<2.0.0,>=0.3.0->voila->geemap) (1.1.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from jupyter-server<2.0.0,>=0.3.0->voila->geemap) (3.1.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server<2.0.0,>=0.3.0->voila->geemap) (1.2.0)
# Requirement already satisfied: whitebox in c:\users\34639\anaconda3\envs\geo_env\lib\site-packages (from whiteboxgui->geemap) (1.5.1)

# %%
import geemap.eefolium as geemap

# %% [markdown]
# # 1 Add a builtin legend to the map

# %%
legends = geemap.builtin_legends
for legend in legends:
    print(legend)
# Out:
# NLCD
# NWI
# MODIS/051/MCD12Q1
# GLOBCOVER
# JAXA/PALSAR
# MODIS/006/MCD12Q1
# Oxford
# AAFC/ACI
# COPERNICUS/CORINE/V20/100m
# COPERNICUS/Landcover/100m/Proba-V/Global
# USDA/NASS/CDL

# %% [markdown]
# Available Land Cover Datasets in Earth Engine
# https://developers.google.com/earth-engine/datasets/tags/landcover
#
# National Land Cover Database (NLCD)
# https://developers.google.com/earth-engine/datasets/catalog/USGS_NLCD

# %%
Map = geemap.Map()

landcover = ee.Image('USGS/NLCD/NLCD2016').select('landcover')
Map.addLayer(landcover, {}, 'NLCD Land Cover')

Map.add_legend(builtin_legend='NLCD')

Map.addLayerControl()

Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_dc62046703ef4c06bc91229804ec0dde%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_dc62046703ef4c06bc91229804ec0dde%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%0A%0A%3C%21doctype%20html%3E%0A%3Chtml%20lang%3D%22en%22%3E%0A%3Chead%3E%0A%20%20%3Cmeta%20charset%3D%22utf-8%22%3E%0A%20%20%3Cmeta%20name%3D%22vi ...

# %% [markdown]
# MODIS Land Cover Type Yearly Global 500m
# https://developers.google.com/earthengine/datasets/catalog/MODIS_006_MCD12Q1

# %%
Map = geemap.Map()

landcover = ee.Image('MODIS/006/MCD12Q1/2013_01_01') \
    .select('LC_Type1') \

igbpLandCoverVis = {
  'min': 1.0,
  'max': 17.0,
  'palette': [
    '05450a', '086a10', '54a708', '78d203', '009900', 'c6b044', 'dcd159',
    'dade48', 'fbff13', 'b6ff05', '27ff87', 'c24f44', 'a5a5a5', 'ff6d4c',
    '69fff8', 'f9ffa4', '1c0dff'
  ],
}

Map.setCenter(6.746, 46.529, 2)
Map.addLayer(landcover, igbpLandCoverVis, 'MODIS Land Cover')

Map.setCenter(6.746, 46.529, 2)
Map.addLayer(landcover, igbpLandCoverVis, 'MODIS Land Cover')
Map.add_legend(builtin_legend='MODIS/006/MCD12Q1')

Map.addLayerControl()

Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_f5f25d8f0d2549b1883fba7b958c2a1a%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_f5f25d8f0d2549b1883fba7b958c2a1a%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%0A%0A%3C%21doctype%20html%3E%0A%3Chtml%20lang%3D%22en%22%3E%0A%3Chead%3E%0A%20%20%3Cmeta%20charset%3D%22utf-8%22%3E%0A%20%20%3Cmeta%20name%3D%22vi ...

# %% [markdown]
# # 2. Add customized legends for Earth Engine data

# %% [markdown]
# There are three ways you can add customized legends for Earth Engine data
#
#     1. Define legend labels and colors
#     2. Defind legend dictionary
#     3. Convert Earth Engine class table to legend dictionary

# %% [markdown]
# ### Define legend keys and colors¶

# %%
Map = geemap.Map()

labels = ['One', 'Two', 'Three', 'Four', 'ect']
 #color can be defined using either hex code or RGB (0-255, 0-255, 0-255)
colors = ['#8DD3C7', '#FFFFB3', '#BEBADA', '#FB8072', '#80B1D3']
# colors = [(255, 0, 0), (127, 255, 0), (127, 18, 25), (36, 70, 180), (96, 68, 123)]

Map.add_legend(title='Legend', labels=labels, colors=colors)
Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_4f8f18c67fa64ae7809eefef59f56ee9%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_4f8f18c67fa64ae7809eefef59f56ee9%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%0A%0A%3C%21doctype%20html%3E%0A%3Chtml%20lang%3D%22en%22%3E%0A%3Chead%3E%0A%20%20%3Cmeta%20charset%3D%22utf-8%22%3E%0A%20%20%3Cmeta%20name%3D%22vi ...

# %% [markdown]
# ## Define a legend dictionary

# %%
Map = geemap.Map()

legend_dict = {
    '11 Open Water': '466b9f',
    '12 Perennial Ice/Snow': 'd1def8',
    '21 Developed, Open Space': 'dec5c5',
    '22 Developed, Low Intensity': 'd99282',
    '23 Developed, Medium Intensity': 'eb0000',
    '24 Developed High Intensity': 'ab0000',
    '31 Barren Land (Rock/Sand/Clay)': 'b3ac9f',
    '41 Deciduous Forest': '68ab5f',
    '42 Evergreen Forest': '1c5f2c',
    '43 Mixed Forest': 'b5c58f',
    '51 Dwarf Scrub': 'af963c',
    '52 Shrub/Scrub': 'ccb879',
    '71 Grassland/Herbaceous': 'dfdfc2',
    '72 Sedge/Herbaceous': 'd1d182',
    '73 Lichens': 'a3cc51',
    '74 Moss': '82ba9e',
    '81 Pasture/Hay': 'dcd939',
    '82 Cultivated Crops': 'ab6c28',
    '90 Woody Wetlands': 'b8d9eb',
    '95 Emergent Herbaceous Wetlands': '6c9fb8'
}

landcover = ee.Image('USGS/NLCD/NLCD2016').select('landcover')
Map.addLayer(landcover, {}, 'NLCD Land Cover')

Map.add_legend(title="NLCD Land Cover Classification", legend_dict=legend_dict)

Map.addLayerControl()

Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_7bd7bb84b91b4f66922a71a38ba05d11%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_7bd7bb84b91b4f66922a71a38ba05d11%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%0A%0A%3C%21doctype%20html%3E%0A%3Chtml%20lang%3D%22en%22%3E%0A%3Chead%3E%0A%20%20%3Cmeta%20charset%3D%22utf-8%22%3E%0A%20%20%3Cmeta%20name%3D%22vi ...

# %% [markdown]
# ## Convert an Earth Engine class table to legend

# %% [markdown]
# For example: MCD12Q1 Land Cover Type Yearly Global 500m
#
# https://developers.google.com/earth-engine/datasets/catalog/MODIS_006_MCD12Q1

# %%
Map = geemap.Map()

ee_class_table = """

Value	Color	Description
0	1c0dff	Water
1	05450a	Evergreen needleleaf forest
2	086a10	Evergreen broadleaf forest
3	54a708	Deciduous needleleaf forest
4	78d203	Deciduous broadleaf forest
5	009900	Mixed forest
6	c6b044	Closed shrublands
7	dcd159	Open shrublands
8	dade48	Woody savannas
9	fbff13	Savannas
10	b6ff05	Grasslands
11	27ff87	Permanent wetlands
12	c24f44	Croplands
13	a5a5a5	Urban and built-up
14	ff6d4c	Cropland/natural vegetation mosaic
15	69fff8	Snow and ice
16	f9ffa4	Barren or sparsely vegetated
254	ffffff	Unclassified

"""

landcover = ee.Image('MODIS/006/MCD12Q1/2013_01_01') \
    .select('LC_Type1') \

igbpLandCoverVis = {
  'min': 1.0,
  'max': 17.0,
  'palette': [
    '05450a', '086a10', '54a708', '78d203', '009900', 'c6b044', 'dcd159',
    'dade48', 'fbff13', 'b6ff05', '27ff87', 'c24f44', 'a5a5a5', 'ff6d4c',
    '69fff8', 'f9ffa4', '1c0dff'
  ],
}

Map.setCenter(6.746, 46.529, 2)
Map.addLayer(landcover, igbpLandCoverVis, 'MODIS Land Cover')

legend_dict = geemap.legend_from_ee(ee_class_table)
Map.add_legend(title="MODIS Global Land Cover", legend_dict=legend_dict)

Map.addLayerControl()

Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_84abc3508ac241028a24c789f08a28ff%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_84abc3508ac241028a24c789f08a28ff%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%0A%0A%3C%21doctype%20html%3E%0A%3Chtml%20lang%3D%22en%22%3E%0A%3Chead%3E%0A%20%20%3Cmeta%20charset%3D%22utf-8%22%3E%0A%20%20%3Cmeta%20name%3D%22vi ...
