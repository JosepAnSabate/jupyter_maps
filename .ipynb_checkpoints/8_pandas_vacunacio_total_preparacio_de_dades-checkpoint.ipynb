# %%
import geopandas as gpd
import geoplot as gplt
import pandas as pd
import json
import random
import requests
import os
import numpy as np

# %% [markdown]
# ## Import CSV from local

# %%
vac_csv = f"C:/capes_sql/vacunacio.csv"
vac_m = pd.read_csv(vac_csv, sep=',')

# %%
vac_m = vac_m.groupby(['MUNICIPI']).sum()
vac_m = vac_m.drop(columns=['SEXE_CODI', 'PROVINCIA_CODI', 'COMARCA_CODI','DISTRICTE_CODI','DOSI'])
vac_m['Municipi'] = vac_m.index

# %%
pobl_csv = f"C:/capes_sql/pomuni.csv"
pobl = pd.read_csv(pobl_csv, sep=';',skiprows=range(0, 4), thousands='.')#comensa a la 5, mo oblidar sep
pobl.head(93)
# Out:
#     Unnamed: 0  Codi municipi        Nom municipi        Edat  Homes  Dones  \
# 0         2020         250019  Abella de la Conca   De 0 anys      0      0
# 1         2020         250019  Abella de la Conca     D'1 any      0      2
# 2         2020         250019  Abella de la Conca   De 2 anys      1      0
# 3         2020         250019  Abella de la Conca   De 3 anys      0      0
# 4         2020         250019  Abella de la Conca   De 4 anys      0      1
# ..         ...            ...                 ...         ...    ...    ...
# 88        2020         250019  Abella de la Conca  De 88 anys      1      2
# 89        2020         250019  Abella de la Conca  De 89 anys      1      1
# 90        2020         250019  Abella de la Conca  De 90 anys      0      0
# 91        2020         250019  Abella de la Conca  De 91 anys      0      0
# 92        2020         250019  Abella de la Conca  De 92 anys      0      0
#
#     Total
# 0       0
# 1       2
# 2       1
# 3       0
# 4       1
# ..    ...
# 88      3
# 89      2
# 90      0
# 91      0
# 92      0
#
# [93 rows x 7 columns]

# %%
# Seleccionar total
pobl =pobl.loc[pobl['Edat'] == "Total"]
pobl.head(93)
# Out:
#       Unnamed: 0  Codi municipi          Nom municipi   Edat   Homes   Dones  \
# 101         2020         250019    Abella de la Conca  Total      99      84
# 203         2020          80018                Abrera  Total    6325    6213
# 305         2020         250024                  Àger  Total     314     266
# 407         2020         250030              Agramunt  Total    2710    2701
# 509         2020          80023    Aguilar de Segarra  Total     148     134
# ...          ...            ...                   ...    ...     ...     ...
# 9077        2020         430213   Barberà de la Conca  Total     260     211
# 9179        2020          82520    Barberà del Vallès  Total   16395   16939
# 9281        2020          80193             Barcelona  Total  790708  873474
# 9383        2020         250426  Baronia de Rialb, la  Total     116     113
# 9485        2020         170160               Bàscara  Total     521     480
#
#         Total
# 101       183
# 203     12538
# 305       580
# 407      5411
# 509       282
# ...       ...
# 9077      471
# 9179    33334
# 9281  1664182
# 9383      229
# 9485     1001
#
# [93 rows x 7 columns]

# %%
pobl.head()
# Out:
#      Unnamed: 0  Codi municipi        Nom municipi   Edat  Homes  Dones  Total
# 101        2020         250019  Abella de la Conca  Total     99     84    183
# 203        2020          80018              Abrera  Total   6325   6213  12538
# 305        2020         250024                Àger  Total    314    266    580
# 407        2020         250030            Agramunt  Total   2710   2701   5411
# 509        2020          80023  Aguilar de Segarra  Total    148    134    282

# %%
pobl['Total'] = pobl['Total'].astype(np.int64)
pobl.head(93)
# Out:
#       Unnamed: 0  Codi municipi          Nom municipi   Edat   Homes   Dones  \
# 101         2020         250019    Abella de la Conca  Total      99      84
# 203         2020          80018                Abrera  Total    6325    6213
# 305         2020         250024                  Àger  Total     314     266
# 407         2020         250030              Agramunt  Total    2710    2701
# 509         2020          80023    Aguilar de Segarra  Total     148     134
# ...          ...            ...                   ...    ...     ...     ...
# 9077        2020         430213   Barberà de la Conca  Total     260     211
# 9179        2020          82520    Barberà del Vallès  Total   16395   16939
# 9281        2020          80193             Barcelona  Total  790708  873474
# 9383        2020         250426  Baronia de Rialb, la  Total     116     113
# 9485        2020         170160               Bàscara  Total     521     480
#
#         Total
# 101       183
# 203     12538
# 305       580
# 407      5411
# 509       282
# ...       ...
# 9077      471
# 9179    33334
# 9281  1664182
# 9383      229
# 9485     1001
#
# [93 rows x 7 columns]

# %%
pobl.dtypes
# Out:
# Unnamed: 0        int64
# Codi municipi     int64
# Nom municipi     object
# Edat             object
# Homes             int64
# Dones             int64
# Total             int64
# dtype: object

# %%
pobl['Habitants'] = pobl['Homes'] + pobl['Dones']
pobl['Habitants'] = pobl['Habitants'].astype(np.int64)
pobl_t = pobl.groupby(['Nom municipi']).sum()
pobl = pobl_t.drop(columns=['Unnamed: 0', 'Dones', 'Homes'])
pobl['Municipi'] = pobl.index
pobl['Municipi'] = pobl['Municipi'].str.upper()

# %%
pobl.head(90)
# Out:
#                      Codi municipi    Total  Habitants             Municipi
# Nom municipi
# Abella de la Conca          250019      183        183   ABELLA DE LA CONCA
# Abrera                       80018    12538      12538               ABRERA
# Agramunt                    250030     5411       5411             AGRAMUNT
# Aguilar de Segarra           80023      282        282   AGUILAR DE SEGARRA
# Agullana                    170010      863        863             AGULLANA
# ...                            ...      ...        ...                  ...
# Banyoles                    170157    20053      20053             BANYOLES
# Barbens                     250411      878        878              BARBENS
# Barberà de la Conca         430213      471        471  BARBERÀ DE LA CONCA
# Barberà del Vallès           82520    33334      33334   BARBERÀ DEL VALLÈS
# Barcelona                    80193  1664182    1664182            BARCELONA
#
# [90 rows x 4 columns]

# %%
pobl.max()
# Out:
# Codi municipi     439076
# Total            1664182
# Habitants        1664182
# Municipi          ÒRRIUS
# dtype: object

# %%
pobl.loc[pobl['Habitants'] > 50000]
# Out:
#                              Codi municipi    Total  Habitants  \
# Nom municipi
# Badalona                             80155   223166     223166
# Barcelona                            80193  1664182    1664182
# Castelldefels                        80569    67460      67460
# Cerdanyola del Vallès                82665    57855      57855
# Cornellà de Llobregat                80734    89936      89936
# Girona                              170792   103369     103369
# Granollers                           80961    62419      62419
# Hospitalet de Llobregat, l'          81017   269382     269382
# Lleida                              251207   140403     140403
# Manresa                              81136    78245      78245
# Mataró                               81213   129661     129661
# Mollet del Vallès                    81249    51600      51600
# Prat de Llobregat, el                81691    65385      65385
# Reus                                431233   106168     106168
# Rubí                                 81846    78591      78591
# Sabadell                             81878   216520     216520
# Sant Boi de Llobregat                82009    84500      84500
# Sant Cugat del Vallès                82055    92977      92977
# Santa Coloma de Gramenet             82457   120443     120443
# Tarragona                           431482   136496     136496
# Terrassa                             82798   223627     223627
# Viladecans                           83015    67197      67197
# Vilanova i la Geltrú                 83073    67733      67733
#
#                                                 Municipi
# Nom municipi
# Badalona                                        BADALONA
# Barcelona                                      BARCELONA
# Castelldefels                              CASTELLDEFELS
# Cerdanyola del Vallès              CERDANYOLA DEL VALLÈS
# Cornellà de Llobregat              CORNELLÀ DE LLOBREGAT
# Girona                                            GIRONA
# Granollers                                    GRANOLLERS
# Hospitalet de Llobregat, l'  HOSPITALET DE LLOBREGAT, L'
# Lleida                                            LLEIDA
# Manresa                                          MANRESA
# Mataró                                            MATARÓ
# Mollet del Vallès                      MOLLET DEL VALLÈS
# Prat de Llobregat, el              PRAT DE LLOBREGAT, EL
# Reus                                                REUS
# Rubí                                                RUBÍ
# Sabadell                                        SABADELL
# Sant Boi de Llobregat              SANT BOI DE LLOBREGAT
# Sant Cugat del Vallès              SANT CUGAT DEL VALLÈS
# Santa Coloma de Gramenet        SANTA COLOMA DE GRAMENET
# Tarragona                                      TARRAGONA
# Terrassa                                        TERRASSA
# Viladecans                                    VILADECANS
# Vilanova i la Geltrú                VILANOVA I LA GELTRÚ

# %% [markdown]
# ###  Joint left

# %%
df_m = pd.merge(pobl, vac_m, how='left')

# %%
df_m['Taxa_vacunacio'] = df_m['RECOMPTE']/df_m['Habitants']*100
df_m = df_m.drop(columns=['Codi municipi','MUNICIPI_CODI','RECOMPTE','Habitants'])
df_m.head(3)
# Out:
#    Total            Municipi  Taxa_vacunacio
# 0    183  ABELLA DE LA CONCA             NaN
# 1  12538              ABRERA       89.535811
# 2   5411            AGRAMUNT      103.844021

# %%
df_m.loc[df_m['Taxa_vacunacio'] > 100]
# Out:
#      Total          Municipi  Taxa_vacunacio
# 2     5411          AGRAMUNT      103.844021
# 5     2512        AIGUAFREDA      101.472930
# 13    1561            ALBESA      104.804612
# 19     238            ALCANÓ      113.025210
# 24     905           ALDOVER      100.994475
# ..     ...               ...             ...
# 929  21035   VILASSAR DE MAR      100.033278
# 938    890  VIMBODÍ I POBLET      110.224719
# 939    450           VINAIXA      113.111111
# 940    425           VINEBRE      104.235294
# 943   1154             XERTA      116.551127
#
# [131 rows x 3 columns]

# %% [markdown]
# # Join data amb spatial data

# %%
import geopandas as gpd
import geoplot as gplt

# %%
geoData=geopandas.read_file('C:/capes_sql/limits_muni_catalunya.geojson')
# trans muni json en maj
geoData['nom_muni'] = geoData['nom_muni'].str.upper()
geoData.head(2)
# Out:
#   codi_ine_6 provincia1 codi_costa codi_ptgc_ comarca1     id   nom_muni  \
# 0        0.0                   0.0                      301.0  PUIG-REIG
# 1        0.0                   0.0                      309.0   BASSELLA
#
#   municipi codi_cadas codi_aft _feature_id codi_ptgc   cap_muni codiine  \
# 0   081751                               4            Puig-reig   08175
# 1   250447                               7             Bassella   25044
#
#                                             geometry
# 0  MULTIPOLYGON (((1.86341 41.91648, 1.86089 41.9...
# 1  MULTIPOLYGON (((1.35053 41.99408, 1.34875 41.9...

# %%
print(geoData.dtypes)
# Out:
# codi_ine_6       object
# provincia1       object
# codi_costa       object
# codi_ptgc_       object
# comarca1         object
# id               object
# nom_muni         object
# municipi         object
# codi_cadas       object
# codi_aft         object
# _feature_id      object
# codi_ptgc        object
# cap_muni         object
# codiine          object
# geometry       geometry
# dtype: object

# %%
fullData = geoData.merge(df_m, left_on=['nom_muni'], right_on=['Municipi'])
fullData.head(2)
# Out:
#   codi_ine_6 provincia1 codi_costa codi_ptgc_ comarca1     id   nom_muni  \
# 0        0.0                   0.0                      301.0  PUIG-REIG
# 1        0.0                   0.0                      309.0   BASSELLA
#
#   municipi codi_cadas codi_aft _feature_id codi_ptgc   cap_muni codiine  \
# 0   081751                               4            Puig-reig   08175
# 1   250447                               7             Bassella   25044
#
#                                             geometry  Total   Municipi  \
# 0  MULTIPOLYGON (((1.86341 41.91648, 1.86089 41.9...   4295  PUIG-REIG
# 1  MULTIPOLYGON (((1.35053 41.99408, 1.34875 41.9...    217   BASSELLA
#
#    Taxa_vacunacio
# 0      108.521537
# 1             NaN

# %%
fullData.plot()
# Out:
# <AxesSubplot:>

# %%
print(fullData.dtypes)
# Out:
# codi_ine_6          object
# provincia1          object
# codi_costa          object
# codi_ptgc_          object
# comarca1            object
# id                  object
# nom_muni            object
# municipi            object
# codi_cadas          object
# codi_aft            object
# _feature_id         object
# codi_ptgc           object
# cap_muni            object
# codiine             object
# geometry          geometry
# Total                int64
# Municipi            object
# Taxa_vacunacio     float64
# dtype: object

# %% [markdown]
# # Export data

# %%
fullData.to_file("C:/capes_sql/vacunesxcent.shp")
# Out:
# <ipython-input-365-1133d6a27131>:1: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   fullData.to_file("C:/capes_sql/vacunesxcent.shp")

# %%
fullData.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Data cleaning

# %% [markdown]
# # 1_ Handlinng missing data

# %%
df = fullData

# %%
pd.isnull(df).sum() #numro de valors null
# Out:
# codi_ine_6          0
# provincia1          0
# codi_costa          0
# codi_ptgc_          0
# comarca1            0
# id                  0
# nom_muni            0
# municipi            0
# codi_cadas          0
# codi_aft            0
# _feature_id         0
# codi_ptgc           0
# cap_muni            0
# codiine             0
# geometry            0
# Total               0
# Municipi            0
# Taxa_vacunacio    155
# dtype: int64

# %%
dfnonulls = df[pd.notnull(df)] # elimina rows amb valors nulls

# %%
dfnonulls.plot()
# Out:
# <AxesSubplot:>

# %%
df.dropna() #Dropping null values ROWS
# Out:
#     codi_ine_6 provincia1 codi_costa codi_ptgc_ comarca1     id  \
# 0          0.0                   0.0                      301.0
# 2          0.0                   0.0                      310.0
# 3          0.0                   0.0                      311.0
# 4          0.0                   0.0                      314.0
# 5          0.0                   0.0                      920.0
# ..         ...        ...        ...        ...      ...    ...
# 809        0.0                   0.0                      664.0
# 810        0.0                   0.0                      889.0
# 811        0.0                   0.0                      665.0
# 812        0.0                   0.0                      669.0
# 813        0.0                   0.0                      670.0
#
#                        nom_muni municipi codi_cadas codi_aft _feature_id  \
# 0                     PUIG-REIG   081751                               4
# 2                          OSOR   171169                               8
# 3                          GURB   081000                               9
# 4                        ORISTÀ   081516                              17
# 5                       TIVENYS   431495                              44
# ..                          ...      ...        ...      ...         ...
# 809  SANT FOST DE CAMPSENTELLES   082093                             941
# 810                 RIUDECANYES   431270                             942
# 811           SARROCA DE LLEIDA   252000                             944
# 812               CASTELLBISBAL   080543                             946
# 813              PREMIÀ DE DALT   082303                             947
#
#     codi_ptgc                    cap_muni codiine  \
# 0                               Puig-reig   08175
# 2                                    Osor   17116
# 3                                    Gurb   08100
# 4                                  Oristà   08151
# 5                                 Tivenys   43149
# ..        ...                         ...     ...
# 809            Sant Fost de Campsentelles   08209
# 810                           Riudecanyes   43127
# 811                     Sarroca de Lleida   25200
# 812                         Castellbisbal   08054
# 813                        Premià de Dalt   08230
#
#                                               geometry  Total  \
# 0    MULTIPOLYGON (((1.86341 41.91648, 1.86089 41.9...   4295
# 2    MULTIPOLYGON (((2.61606 41.92397, 2.61418 41.9...    428
# 3    MULTIPOLYGON (((2.28961 41.96064, 2.28857 41.9...   2713
# 4    MULTIPOLYGON (((2.13624 41.95468, 2.13621 41.9...    549
# 5    MULTIPOLYGON (((0.61764 40.88993, 0.60633 40.8...    902
# ..                                                 ...    ...
# 809  MULTIPOLYGON (((2.20337 41.50385, 2.20366 41.5...   8853
# 810  MULTIPOLYGON (((0.98107 41.13371, 0.97988 41.1...   1146
# 811  MULTIPOLYGON (((0.52870 41.43169, 0.52977 41.4...    358
# 812  MULTIPOLYGON (((1.98996 41.43990, 1.98881 41.4...  12539
# 813  MULTIPOLYGON (((2.34402 41.48822, 2.34288 41.4...  10441
#
#                        Municipi  Taxa_vacunacio
# 0                     PUIG-REIG      108.521537
# 2                          OSOR       82.009346
# 3                          GURB       99.373387
# 4                        ORISTÀ       95.810565
# 5                       TIVENYS      119.623060
# ..                          ...             ...
# 809  SANT FOST DE CAMPSENTELLES      100.463120
# 810                 RIUDECANYES       81.151832
# 811           SARROCA DE LLEIDA      122.346369
# 812               CASTELLBISBAL       86.498126
# 813              PREMIÀ DE DALT       91.111962
#
# [659 rows x 18 columns]

# %%
df.info() # veru useful!!!!!
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 814 entries, 0 to 813
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   codi_ine_6      814 non-null    object
#  1   provincia1      814 non-null    object
#  2   codi_costa      814 non-null    object
#  3   codi_ptgc_      814 non-null    object
#  4   comarca1        814 non-null    object
#  5   id              814 non-null    object
#  6   nom_muni        814 non-null    object
#  7   municipi        814 non-null    object
#  8   codi_cadas      814 non-null    object
#  9   codi_aft        814 non-null    object
#  10  _feature_id     814 non-null    object
#  11  codi_ptgc       814 non-null    object
#  12  cap_muni        814 non-null    object
#  13  codiine         814 non-null    object
#  14  geometry        814 non-null    geometry
#  15  Total           814 non-null    int64
#  16  Municipi        814 non-null    object
#  17  Taxa_vacunacio  659 non-null    float64
# dtypes: float64(1), geometry(1), int64(1), object(15)
# memory usage: 153.1+ KB

# %%
df.isnull().sum()
# Out:
# codi_ine_6          0
# provincia1          0
# codi_costa          0
# codi_ptgc_          0
# comarca1            0
# id                  0
# nom_muni            0
# municipi            0
# codi_cadas          0
# codi_aft            0
# _feature_id         0
# codi_ptgc           0
# cap_muni            0
# codiine             0
# geometry            0
# Total               0
# Municipi            0
# Taxa_vacunacio    155
# dtype: int64

# %%
df.dropna(axis=1)  # axis='columns' also works, elimina columns amb null values
# Out:
#     codi_ine_6 provincia1 codi_costa codi_ptgc_ comarca1     id  \
# 0          0.0                   0.0                      301.0
# 1          0.0                   0.0                      309.0
# 2          0.0                   0.0                      310.0
# 3          0.0                   0.0                      311.0
# 4          0.0                   0.0                      314.0
# ..         ...        ...        ...        ...      ...    ...
# 809        0.0                   0.0                      664.0
# 810        0.0                   0.0                      889.0
# 811        0.0                   0.0                      665.0
# 812        0.0                   0.0                      669.0
# 813        0.0                   0.0                      670.0
#
#                        nom_muni municipi codi_cadas codi_aft _feature_id  \
# 0                     PUIG-REIG   081751                               4
# 1                      BASSELLA   250447                               7
# 2                          OSOR   171169                               8
# 3                          GURB   081000                               9
# 4                        ORISTÀ   081516                              17
# ..                          ...      ...        ...      ...         ...
# 809  SANT FOST DE CAMPSENTELLES   082093                             941
# 810                 RIUDECANYES   431270                             942
# 811           SARROCA DE LLEIDA   252000                             944
# 812               CASTELLBISBAL   080543                             946
# 813              PREMIÀ DE DALT   082303                             947
#
#     codi_ptgc                    cap_muni codiine  \
# 0                               Puig-reig   08175
# 1                                Bassella   25044
# 2                                    Osor   17116
# 3                                    Gurb   08100
# 4                                  Oristà   08151
# ..        ...                         ...     ...
# 809            Sant Fost de Campsentelles   08209
# 810                           Riudecanyes   43127
# 811                     Sarroca de Lleida   25200
# 812                         Castellbisbal   08054
# 813                        Premià de Dalt   08230
#
#                                               geometry  Total  \
# 0    MULTIPOLYGON (((1.86341 41.91648, 1.86089 41.9...   4295
# 1    MULTIPOLYGON (((1.35053 41.99408, 1.34875 41.9...    217
# 2    MULTIPOLYGON (((2.61606 41.92397, 2.61418 41.9...    428
# 3    MULTIPOLYGON (((2.28961 41.96064, 2.28857 41.9...   2713
# 4    MULTIPOLYGON (((2.13624 41.95468, 2.13621 41.9...    549
# ..                                                 ...    ...
# 809  MULTIPOLYGON (((2.20337 41.50385, 2.20366 41.5...   8853
# 810  MULTIPOLYGON (((0.98107 41.13371, 0.97988 41.1...   1146
# 811  MULTIPOLYGON (((0.52870 41.43169, 0.52977 41.4...    358
# 812  MULTIPOLYGON (((1.98996 41.43990, 1.98881 41.4...  12539
# 813  MULTIPOLYGON (((2.34402 41.48822, 2.34288 41.4...  10441
#
#                        Municipi
# 0                     PUIG-REIG
# 1                      BASSELLA
# 2                          OSOR
# 3                          GURB
# 4                        ORISTÀ
# ..                          ...
# 809  SANT FOST DE CAMPSENTELLES
# 810                 RIUDECANYES
# 811           SARROCA DE LLEIDA
# 812               CASTELLBISBAL
# 813              PREMIÀ DE DALT
#
# [814 rows x 17 columns]

# %%
df.dropna(how='all')# drop the col o rows that have all the values as null
# Out:
#     codi_ine_6 provincia1 codi_costa codi_ptgc_ comarca1     id  \
# 0          0.0                   0.0                      301.0
# 1          0.0                   0.0                      309.0
# 2          0.0                   0.0                      310.0
# 3          0.0                   0.0                      311.0
# 4          0.0                   0.0                      314.0
# ..         ...        ...        ...        ...      ...    ...
# 809        0.0                   0.0                      664.0
# 810        0.0                   0.0                      889.0
# 811        0.0                   0.0                      665.0
# 812        0.0                   0.0                      669.0
# 813        0.0                   0.0                      670.0
#
#                        nom_muni municipi codi_cadas codi_aft _feature_id  \
# 0                     PUIG-REIG   081751                               4
# 1                      BASSELLA   250447                               7
# 2                          OSOR   171169                               8
# 3                          GURB   081000                               9
# 4                        ORISTÀ   081516                              17
# ..                          ...      ...        ...      ...         ...
# 809  SANT FOST DE CAMPSENTELLES   082093                             941
# 810                 RIUDECANYES   431270                             942
# 811           SARROCA DE LLEIDA   252000                             944
# 812               CASTELLBISBAL   080543                             946
# 813              PREMIÀ DE DALT   082303                             947
#
#     codi_ptgc                    cap_muni codiine  \
# 0                               Puig-reig   08175
# 1                                Bassella   25044
# 2                                    Osor   17116
# 3                                    Gurb   08100
# 4                                  Oristà   08151
# ..        ...                         ...     ...
# 809            Sant Fost de Campsentelles   08209
# 810                           Riudecanyes   43127
# 811                     Sarroca de Lleida   25200
# 812                         Castellbisbal   08054
# 813                        Premià de Dalt   08230
#
#                                               geometry  Total  \
# 0    MULTIPOLYGON (((1.86341 41.91648, 1.86089 41.9...   4295
# 1    MULTIPOLYGON (((1.35053 41.99408, 1.34875 41.9...    217
# 2    MULTIPOLYGON (((2.61606 41.92397, 2.61418 41.9...    428
# 3    MULTIPOLYGON (((2.28961 41.96064, 2.28857 41.9...   2713
# 4    MULTIPOLYGON (((2.13624 41.95468, 2.13621 41.9...    549
# ..                                                 ...    ...
# 809  MULTIPOLYGON (((2.20337 41.50385, 2.20366 41.5...   8853
# 810  MULTIPOLYGON (((0.98107 41.13371, 0.97988 41.1...   1146
# 811  MULTIPOLYGON (((0.52870 41.43169, 0.52977 41.4...    358
# 812  MULTIPOLYGON (((1.98996 41.43990, 1.98881 41.4...  12539
# 813  MULTIPOLYGON (((2.34402 41.48822, 2.34288 41.4...  10441
#
#                        Municipi  Taxa_vacunacio
# 0                     PUIG-REIG      108.521537
# 1                      BASSELLA             NaN
# 2                          OSOR       82.009346
# 3                          GURB       99.373387
# 4                        ORISTÀ       95.810565
# ..                          ...             ...
# 809  SANT FOST DE CAMPSENTELLES      100.463120
# 810                 RIUDECANYES       81.151832
# 811           SARROCA DE LLEIDA      122.346369
# 812               CASTELLBISBAL       86.498126
# 813              PREMIÀ DE DALT       91.111962
#
# [814 rows x 18 columns]

# %%
df.dropna(thresh=3)# drop col or rowa with 3 or more null values
# Out:
#     codi_ine_6 provincia1 codi_costa codi_ptgc_ comarca1     id  \
# 0          0.0                   0.0                      301.0
# 1          0.0                   0.0                      309.0
# 2          0.0                   0.0                      310.0
# 3          0.0                   0.0                      311.0
# 4          0.0                   0.0                      314.0
# ..         ...        ...        ...        ...      ...    ...
# 809        0.0                   0.0                      664.0
# 810        0.0                   0.0                      889.0
# 811        0.0                   0.0                      665.0
# 812        0.0                   0.0                      669.0
# 813        0.0                   0.0                      670.0
#
#                        nom_muni municipi codi_cadas codi_aft _feature_id  \
# 0                     PUIG-REIG   081751                               4
# 1                      BASSELLA   250447                               7
# 2                          OSOR   171169                               8
# 3                          GURB   081000                               9
# 4                        ORISTÀ   081516                              17
# ..                          ...      ...        ...      ...         ...
# 809  SANT FOST DE CAMPSENTELLES   082093                             941
# 810                 RIUDECANYES   431270                             942
# 811           SARROCA DE LLEIDA   252000                             944
# 812               CASTELLBISBAL   080543                             946
# 813              PREMIÀ DE DALT   082303                             947
#
#     codi_ptgc                    cap_muni codiine  \
# 0                               Puig-reig   08175
# 1                                Bassella   25044
# 2                                    Osor   17116
# 3                                    Gurb   08100
# 4                                  Oristà   08151
# ..        ...                         ...     ...
# 809            Sant Fost de Campsentelles   08209
# 810                           Riudecanyes   43127
# 811                     Sarroca de Lleida   25200
# 812                         Castellbisbal   08054
# 813                        Premià de Dalt   08230
#
#                                               geometry  Total  \
# 0    MULTIPOLYGON (((1.86341 41.91648, 1.86089 41.9...   4295
# 1    MULTIPOLYGON (((1.35053 41.99408, 1.34875 41.9...    217
# 2    MULTIPOLYGON (((2.61606 41.92397, 2.61418 41.9...    428
# 3    MULTIPOLYGON (((2.28961 41.96064, 2.28857 41.9...   2713
# 4    MULTIPOLYGON (((2.13624 41.95468, 2.13621 41.9...    549
# ..                                                 ...    ...
# 809  MULTIPOLYGON (((2.20337 41.50385, 2.20366 41.5...   8853
# 810  MULTIPOLYGON (((0.98107 41.13371, 0.97988 41.1...   1146
# 811  MULTIPOLYGON (((0.52870 41.43169, 0.52977 41.4...    358
# 812  MULTIPOLYGON (((1.98996 41.43990, 1.98881 41.4...  12539
# 813  MULTIPOLYGON (((2.34402 41.48822, 2.34288 41.4...  10441
#
#                        Municipi  Taxa_vacunacio
# 0                     PUIG-REIG      108.521537
# 1                      BASSELLA             NaN
# 2                          OSOR       82.009346
# 3                          GURB       99.373387
# 4                        ORISTÀ       95.810565
# ..                          ...             ...
# 809  SANT FOST DE CAMPSENTELLES      100.463120
# 810                 RIUDECANYES       81.151832
# 811           SARROCA DE LLEIDA      122.346369
# 812               CASTELLBISBAL       86.498126
# 813              PREMIÀ DE DALT       91.111962
#
# [814 rows x 18 columns]

# %% [markdown]
# # Filling null values

# %%
df.fillna(df) # fill the null values as 0
# Out:
#     codi_ine_6 provincia1 codi_costa codi_ptgc_ comarca1     id  \
# 0          0.0                   0.0                      301.0
# 1          0.0                   0.0                      309.0
# 2          0.0                   0.0                      310.0
# 3          0.0                   0.0                      311.0
# 4          0.0                   0.0                      314.0
# ..         ...        ...        ...        ...      ...    ...
# 809        0.0                   0.0                      664.0
# 810        0.0                   0.0                      889.0
# 811        0.0                   0.0                      665.0
# 812        0.0                   0.0                      669.0
# 813        0.0                   0.0                      670.0
#
#                        nom_muni municipi codi_cadas codi_aft _feature_id  \
# 0                     PUIG-REIG   081751                               4
# 1                      BASSELLA   250447                               7
# 2                          OSOR   171169                               8
# 3                          GURB   081000                               9
# 4                        ORISTÀ   081516                              17
# ..                          ...      ...        ...      ...         ...
# 809  SANT FOST DE CAMPSENTELLES   082093                             941
# 810                 RIUDECANYES   431270                             942
# 811           SARROCA DE LLEIDA   252000                             944
# 812               CASTELLBISBAL   080543                             946
# 813              PREMIÀ DE DALT   082303                             947
#
#     codi_ptgc                    cap_muni codiine  \
# 0                               Puig-reig   08175
# 1                                Bassella   25044
# 2                                    Osor   17116
# 3                                    Gurb   08100
# 4                                  Oristà   08151
# ..        ...                         ...     ...
# 809            Sant Fost de Campsentelles   08209
# 810                           Riudecanyes   43127
# 811                     Sarroca de Lleida   25200
# 812                         Castellbisbal   08054
# 813                        Premià de Dalt   08230
#
#                                               geometry  Total  \
# 0    MULTIPOLYGON (((1.86341 41.91648, 1.86089 41.9...   4295
# 1    MULTIPOLYGON (((1.35053 41.99408, 1.34875 41.9...    217
# 2    MULTIPOLYGON (((2.61606 41.92397, 2.61418 41.9...    428
# 3    MULTIPOLYGON (((2.28961 41.96064, 2.28857 41.9...   2713
# 4    MULTIPOLYGON (((2.13624 41.95468, 2.13621 41.9...    549
# ..                                                 ...    ...
# 809  MULTIPOLYGON (((2.20337 41.50385, 2.20366 41.5...   8853
# 810  MULTIPOLYGON (((0.98107 41.13371, 0.97988 41.1...   1146
# 811  MULTIPOLYGON (((0.52870 41.43169, 0.52977 41.4...    358
# 812  MULTIPOLYGON (((1.98996 41.43990, 1.98881 41.4...  12539
# 813  MULTIPOLYGON (((2.34402 41.48822, 2.34288 41.4...  10441
#
#                        Municipi  Taxa_vacunacio
# 0                     PUIG-REIG      108.521537
# 1                      BASSELLA             NaN
# 2                          OSOR       82.009346
# 3                          GURB       99.373387
# 4                        ORISTÀ       95.810565
# ..                          ...             ...
# 809  SANT FOST DE CAMPSENTELLES      100.463120
# 810                 RIUDECANYES       81.151832
# 811           SARROCA DE LLEIDA      122.346369
# 812               CASTELLBISBAL       86.498126
# 813              PREMIÀ DE DALT       91.111962
#
# [814 rows x 18 columns]

# %%
df.fillna(df.mean()) # fill the null values as mean
# Out:
#     codi_ine_6 provincia1 codi_costa codi_ptgc_ comarca1     id  \
# 0          0.0                   0.0                      301.0
# 1          0.0                   0.0                      309.0
# 2          0.0                   0.0                      310.0
# 3          0.0                   0.0                      311.0
# 4          0.0                   0.0                      314.0
# ..         ...        ...        ...        ...      ...    ...
# 809        0.0                   0.0                      664.0
# 810        0.0                   0.0                      889.0
# 811        0.0                   0.0                      665.0
# 812        0.0                   0.0                      669.0
# 813        0.0                   0.0                      670.0
#
#                        nom_muni municipi codi_cadas codi_aft _feature_id  \
# 0                     PUIG-REIG   081751                               4
# 1                      BASSELLA   250447                               7
# 2                          OSOR   171169                               8
# 3                          GURB   081000                               9
# 4                        ORISTÀ   081516                              17
# ..                          ...      ...        ...      ...         ...
# 809  SANT FOST DE CAMPSENTELLES   082093                             941
# 810                 RIUDECANYES   431270                             942
# 811           SARROCA DE LLEIDA   252000                             944
# 812               CASTELLBISBAL   080543                             946
# 813              PREMIÀ DE DALT   082303                             947
#
#     codi_ptgc                    cap_muni codiine  \
# 0                               Puig-reig   08175
# 1                                Bassella   25044
# 2                                    Osor   17116
# 3                                    Gurb   08100
# 4                                  Oristà   08151
# ..        ...                         ...     ...
# 809            Sant Fost de Campsentelles   08209
# 810                           Riudecanyes   43127
# 811                     Sarroca de Lleida   25200
# 812                         Castellbisbal   08054
# 813                        Premià de Dalt   08230
#
#                                               geometry  Total  \
# 0    MULTIPOLYGON (((1.86341 41.91648, 1.86089 41.9...   4295
# 1    MULTIPOLYGON (((1.35053 41.99408, 1.34875 41.9...    217
# 2    MULTIPOLYGON (((2.61606 41.92397, 2.61418 41.9...    428
# 3    MULTIPOLYGON (((2.28961 41.96064, 2.28857 41.9...   2713
# 4    MULTIPOLYGON (((2.13624 41.95468, 2.13621 41.9...    549
# ..                                                 ...    ...
# 809  MULTIPOLYGON (((2.20337 41.50385, 2.20366 41.5...   8853
# 810  MULTIPOLYGON (((0.98107 41.13371, 0.97988 41.1...   1146
# 811  MULTIPOLYGON (((0.52870 41.43169, 0.52977 41.4...    358
# 812  MULTIPOLYGON (((1.98996 41.43990, 1.98881 41.4...  12539
# 813  MULTIPOLYGON (((2.34402 41.48822, 2.34288 41.4...  10441
#
#                        Municipi  Taxa_vacunacio
# 0                     PUIG-REIG      108.521537
# 1                      BASSELLA       91.126713
# 2                          OSOR       82.009346
# 3                          GURB       99.373387
# 4                        ORISTÀ       95.810565
# ..                          ...             ...
# 809  SANT FOST DE CAMPSENTELLES      100.463120
# 810                 RIUDECANYES       81.151832
# 811           SARROCA DE LLEIDA      122.346369
# 812               CASTELLBISBAL       86.498126
# 813              PREMIÀ DE DALT       91.111962
#
# [814 rows x 18 columns]

# %% [markdown]
# # Filling nulls with contiguous (close) values

# %%
#df.fillna(method='ffill') # null as the same last value  SERIES

# %% [markdown]
# # Filling null values on DataFrames

# %%
df.fillna({'Taxa_vacunacio': df['Taxa_vacunacio'].mean()}) #fill missing data with this value
# Out:
#     codi_ine_6 provincia1 codi_costa codi_ptgc_ comarca1     id  \
# 0          0.0                   0.0                      301.0
# 1          0.0                   0.0                      309.0
# 2          0.0                   0.0                      310.0
# 3          0.0                   0.0                      311.0
# 4          0.0                   0.0                      314.0
# ..         ...        ...        ...        ...      ...    ...
# 809        0.0                   0.0                      664.0
# 810        0.0                   0.0                      889.0
# 811        0.0                   0.0                      665.0
# 812        0.0                   0.0                      669.0
# 813        0.0                   0.0                      670.0
#
#                        nom_muni municipi codi_cadas codi_aft _feature_id  \
# 0                     PUIG-REIG   081751                               4
# 1                      BASSELLA   250447                               7
# 2                          OSOR   171169                               8
# 3                          GURB   081000                               9
# 4                        ORISTÀ   081516                              17
# ..                          ...      ...        ...      ...         ...
# 809  SANT FOST DE CAMPSENTELLES   082093                             941
# 810                 RIUDECANYES   431270                             942
# 811           SARROCA DE LLEIDA   252000                             944
# 812               CASTELLBISBAL   080543                             946
# 813              PREMIÀ DE DALT   082303                             947
#
#     codi_ptgc                    cap_muni codiine  \
# 0                               Puig-reig   08175
# 1                                Bassella   25044
# 2                                    Osor   17116
# 3                                    Gurb   08100
# 4                                  Oristà   08151
# ..        ...                         ...     ...
# 809            Sant Fost de Campsentelles   08209
# 810                           Riudecanyes   43127
# 811                     Sarroca de Lleida   25200
# 812                         Castellbisbal   08054
# 813                        Premià de Dalt   08230
#
#                                               geometry  Total  \
# 0    MULTIPOLYGON (((1.86341 41.91648, 1.86089 41.9...   4295
# 1    MULTIPOLYGON (((1.35053 41.99408, 1.34875 41.9...    217
# 2    MULTIPOLYGON (((2.61606 41.92397, 2.61418 41.9...    428
# 3    MULTIPOLYGON (((2.28961 41.96064, 2.28857 41.9...   2713
# 4    MULTIPOLYGON (((2.13624 41.95468, 2.13621 41.9...    549
# ..                                                 ...    ...
# 809  MULTIPOLYGON (((2.20337 41.50385, 2.20366 41.5...   8853
# 810  MULTIPOLYGON (((0.98107 41.13371, 0.97988 41.1...   1146
# 811  MULTIPOLYGON (((0.52870 41.43169, 0.52977 41.4...    358
# 812  MULTIPOLYGON (((1.98996 41.43990, 1.98881 41.4...  12539
# 813  MULTIPOLYGON (((2.34402 41.48822, 2.34288 41.4...  10441
#
#                        Municipi  Taxa_vacunacio
# 0                     PUIG-REIG      108.521537
# 1                      BASSELLA       91.126713
# 2                          OSOR       82.009346
# 3                          GURB       99.373387
# 4                        ORISTÀ       95.810565
# ..                          ...             ...
# 809  SANT FOST DE CAMPSENTELLES      100.463120
# 810                 RIUDECANYES       81.151832
# 811           SARROCA DE LLEIDA      122.346369
# 812               CASTELLBISBAL       86.498126
# 813              PREMIÀ DE DALT       91.111962
#
# [814 rows x 18 columns]

# %%
#df.fillna(method='ffill', axis=0) # row, the las value row

# %%
df.fillna(method='ffill', axis=1) # coldf.fillna(method='ffill', axis=1) # fill the value with the value of the last col
# Out:
#     codi_ine_6 provincia1 codi_costa codi_ptgc_ comarca1     id  \
# 0          0.0                   0.0                      301.0
# 1          0.0                   0.0                      309.0
# 2          0.0                   0.0                      310.0
# 3          0.0                   0.0                      311.0
# 4          0.0                   0.0                      314.0
# ..         ...        ...        ...        ...      ...    ...
# 809        0.0                   0.0                      664.0
# 810        0.0                   0.0                      889.0
# 811        0.0                   0.0                      665.0
# 812        0.0                   0.0                      669.0
# 813        0.0                   0.0                      670.0
#
#                        nom_muni municipi codi_cadas codi_aft _feature_id  \
# 0                     PUIG-REIG   081751                               4
# 1                      BASSELLA   250447                               7
# 2                          OSOR   171169                               8
# 3                          GURB   081000                               9
# 4                        ORISTÀ   081516                              17
# ..                          ...      ...        ...      ...         ...
# 809  SANT FOST DE CAMPSENTELLES   082093                             941
# 810                 RIUDECANYES   431270                             942
# 811           SARROCA DE LLEIDA   252000                             944
# 812               CASTELLBISBAL   080543                             946
# 813              PREMIÀ DE DALT   082303                             947
#
#     codi_ptgc                    cap_muni codiine  \
# 0                               Puig-reig   08175
# 1                                Bassella   25044
# 2                                    Osor   17116
# 3                                    Gurb   08100
# 4                                  Oristà   08151
# ..        ...                         ...     ...
# 809            Sant Fost de Campsentelles   08209
# 810                           Riudecanyes   43127
# 811                     Sarroca de Lleida   25200
# 812                         Castellbisbal   08054
# 813                        Premià de Dalt   08230
#
#                                               geometry  Total  \
# 0    MULTIPOLYGON (((1.86341 41.91648, 1.86089 41.9...   4295
# 1    MULTIPOLYGON (((1.35053 41.99408, 1.34875 41.9...    217
# 2    MULTIPOLYGON (((2.61606 41.92397, 2.61418 41.9...    428
# 3    MULTIPOLYGON (((2.28961 41.96064, 2.28857 41.9...   2713
# 4    MULTIPOLYGON (((2.13624 41.95468, 2.13621 41.9...    549
# ..                                                 ...    ...
# 809  MULTIPOLYGON (((2.20337 41.50385, 2.20366 41.5...   8853
# 810  MULTIPOLYGON (((0.98107 41.13371, 0.97988 41.1...   1146
# 811  MULTIPOLYGON (((0.52870 41.43169, 0.52977 41.4...    358
# 812  MULTIPOLYGON (((1.98996 41.43990, 1.98881 41.4...  12539
# 813  MULTIPOLYGON (((2.34402 41.48822, 2.34288 41.4...  10441
#
#                        Municipi Taxa_vacunacio
# 0                     PUIG-REIG     108.521537
# 1                      BASSELLA       BASSELLA
# 2                          OSOR      82.009346
# 3                          GURB      99.373387
# 4                        ORISTÀ      95.810565
# ..                          ...            ...
# 809  SANT FOST DE CAMPSENTELLES      100.46312
# 810                 RIUDECANYES      81.151832
# 811           SARROCA DE LLEIDA     122.346369
# 812               CASTELLBISBAL      86.498126
# 813              PREMIÀ DE DALT      91.111962
#
# [814 rows x 18 columns]

# %% [markdown]
# # Checking if there are NAs

# %%
df.dropna().count()
# Out:
# codi_ine_6        659
# provincia1        659
# codi_costa        659
# codi_ptgc_        659
# comarca1          659
# id                659
# nom_muni          659
# municipi          659
# codi_cadas        659
# codi_aft          659
# _feature_id       659
# codi_ptgc         659
# cap_muni          659
# codiine           659
# geometry          659
# Total             659
# Municipi          659
# Taxa_vacunacio    659
# dtype: int64

# %%
len(df)
# Out:
# 814

# %%
df.count()
# Out:
# codi_ine_6        814
# provincia1        814
# codi_costa        814
# codi_ptgc_        814
# comarca1          814
# id                814
# nom_muni          814
# municipi          814
# codi_cadas        814
# codi_aft          814
# _feature_id       814
# codi_ptgc         814
# cap_muni          814
# codiine           814
# geometry          814
# Total             814
# Municipi          814
# Taxa_vacunacio    659
# dtype: int64

# %%
missing_values = df.count() != len(df)
missing_values
# Out:
# codi_ine_6        False
# provincia1        False
# codi_costa        False
# codi_ptgc_        False
# comarca1          False
# id                False
# nom_muni          False
# municipi          False
# codi_cadas        False
# codi_aft          False
# _feature_id       False
# codi_ptgc         False
# cap_muni          False
# codiine           False
# geometry          False
# Total             False
# Municipi          False
# Taxa_vacunacio     True
# dtype: bool

# %% [markdown]
# # 2 Cleaning not-null values

# %% [markdown]
# ### Finding Unique Values

# %%
df['provincia1'].unique()
# Out:
# array([''], dtype=object)

# %%
df['Municipi'].unique()
# Out:
# array(['PUIG-REIG', 'BASSELLA', 'OSOR', 'GURB', 'ORISTÀ', 'TIVENYS',
#        'MIERES', 'SANT GREGORI', 'BANYOLES', 'SANT FELIU DE PALLEROLS',
#        'SANT ANIOL DE FINESTRES', 'LLUÇÀ', 'CORNELLÀ DEL TERRI',
#        'LLIMIANA', 'ÀGER', 'ISONA I CONCA DELLÀ', 'OLIUS',
#        'VILANOVA DE MEIÀ', 'AMER', 'SOLSONA', 'GIRONA', 'ARNES',
#        'CARDONA', 'MONTMAJOR', 'RUPIT I PRUIT', 'PALOL DE REVARDIT',
#        'SANT JULIÀ DE RAMIS', 'ARTESA DE SEGRE', 'TORROELLA DE MONTGRÍ',
#        'MONT-ROIG DEL CAMP', 'TIVISSA', 'SALOU', 'CASERES',
#        "VANDELLÒS I L'HOSPITALET DE L'INFANT", 'BENIFALLET',
#        "CORBERA D'EBRE", 'CADAQUÉS', 'JOSA I TUIXÉN', 'GOMBRÈN', 'CABÓ',
#        'GANDESA', 'ROQUETES', 'DELTEBRE', 'MAS DE BARBERANS', 'ULLDECONA',
#        'AMPOSTA', 'ALCANAR', 'SANT CARLES DE LA RÀPITA', 'TARRAGONA',
#        'VILA-SECA', 'BEUDA', 'PERALADA', 'SANT LLORENÇ DE LA MUGA',
#        'RIBES DE FRESER', 'MONTAGUT I OIX', 'SANT JOAN DE LES ABADESSES',
#        'SANT PERE PESCADOR', 'PORTBOU', 'ALCOVER', 'VILADEMULS',
#        'SANTA PAU', 'ODÈN', 'GUIXERS', 'TREMP', 'ESPONELLÀ', 'BORREDÀ',
#        'VILALLER', 'VIELHA E MIJARAN', 'ALT ÀNEU', 'LLAVORSÍ', 'SORT',
#        'RIALP', 'FARRERA', 'LLES DE CERDANYA', 'SARROCA DE BELLERA',
#        'BELLVER DE CERDANYA', 'RABÓS', 'SORIGUERA', 'GÓSOL', 'NAVATA',
#        'RIPOLL', 'ROSES', 'DARNIUS', 'GARCIA', 'LLANÇÀ',
#        'MAÇANET DE CABRENYS', 'COLERA', 'ALBANYÀ', 'VILANOVA I LA GELTRÚ',
#        'FALSET', "RIBERA D'URGELLET", 'CASTELL DE MUR', 'CUNIT', 'BATEA',
#        'CAMPRODON', 'RIU DE CERDANYA', 'SITGES', 'VILALBA DELS ARCS',
#        'CALAFELL', 'GRATALLOPS', 'RODA DE BERÀ', 'VILAVERD', 'FLIX',
#        'BARCELONA', 'TORREDEMBARRA', 'SANT ESTEVE SESROVIRES', 'VINAIXA',
#        'QUEROL', 'TALAVERA', 'RIUMORS', 'VALL DE CARDÓS', 'GAVÀ', 'SERÒS',
#        'SARRAL', 'BEGUR', 'AVINYÓ', 'LLAMBILLES', 'ARBECA', 'BIOSCA',
#        'SANT ANDREU DE LLAVANERES', 'ESPARREGUERA', 'MURA',
#        'CERVIÀ DE LES GARRIGUES', 'SANT MARTÍ DE TOUS', 'SALLENT',
#        'TARADELL', 'VALL-LLOBREGA', 'VILADRAU', 'SANT MATEU DE BAGES',
#        'SABADELL', 'PIERA', 'PUIGVERD DE LLEIDA', 'VILOBÍ DEL PENEDÈS',
#        'TORREFETA I FLOREJACS', 'MONT-RAS', 'MOIÀ', 'LLAGOSTERA',
#        'MATARÓ', 'RUBIÓ', 'OS DE BALAGUER', 'ARBÚCIES', 'TOSSA DE MAR',
#        'ÒDENA', "CASTELL-PLATJA D'ARO", 'SEVA', 'LLORET DE MAR',
#        'CASTELLNOU DE SEANA', "RIBERA D'ONDARA", 'BLANES',
#        "BELLMUNT D'URGELL", 'CASTELLBELL I EL VILAR', 'MONTSENY',
#        'SUBIRATS', 'MONTBLANC', 'SANT MARTÍ DE CENTELLES', 'TAGAMANENT',
#        'ALMACELLES', 'VILANANT', 'AVINYONET DEL PENEDÈS', 'FONDARELLA',
#        "IVARS D'URGELL", 'VACARISSES', 'TERRASSA', 'GRANYENA DE SEGARRA',
#        'SANTA MARIA DE MIRALLES', 'LLEIDA', 'TALAMANCA',
#        'VESPELLA DE GAIÀ', 'ANGLÈS', 'MONTMANEU', 'MASQUEFA', 'RUBÍ',
#        'VIC', 'OLIOLA', 'MONTCADA I REIXAC', 'SANT CUGAT DEL VALLÈS',
#        'CORÇÀ', "CABRERA D'ANOIA", 'SANTA CECÍLIA DE VOLTREGÀ',
#        'PORQUERES', 'SANT BARTOMEU DEL GRAU', 'PALS', 'PALAU-SATOR',
#        'TIURANA', 'VIVER I SERRATEIX', 'PINELL DE SOLSONÈS', 'MADREMANYA',
#        'CLARIANA DE CARDENER', 'ALÒS DE BALAGUER', 'VILANOVA DE SAU',
#        'JUIÀ', 'SANT JULIÀ DEL LLOR I BONMATÍ', 'RODA DE TER', 'SALT',
#        'FORALLAC', 'MUNTANYOLA', 'VILAÜR', 'SANT ESTEVE DE LA SARGA',
#        "CRUÏLLES, MONELLS I SANT SADURNÍ DE L'HEURA", 'MANLLEU', 'QUART',
#        'PACS DEL PENEDÈS', 'TAVÈRNOLES', 'SANT HILARI SACALM',
#        'CASTELLAR DEL RIU', 'BESCANÓ', 'SANT FELIU SASSERRA',
#        'FONTCOBERTA', 'GAVET DE LA CONCA', 'PARLAVÀ', 'RINER', 'GAIÀ',
#        'SANT LLORENÇ DE MORUNYS', 'LLOBERA', "VILANOVA DE L'AGUDA",
#        'ALPENS', "SANT MARTÍ D'ALBARS", 'SANTA MARIA DE BESORA',
#        'SAUS, CAMALLERA I LLAMPAIES', 'SOBREMUNT', 'VILADAMAT',
#        'SARRIÀ DE TER', 'PERAMOLA', 'SANT HIPÒLIT DE VOLTREGÀ',
#        'VILOPRIU', 'SORA', 'NAVÈS', 'MONTESQUIU', 'GARRIGOLES',
#        'SANT QUIRZE DE BESORA', 'SANT JORDI DESVALLS', 'BERGA', 'ALBONS',
#        'COLOMERS', 'CAPOLAT', 'SANT PERE DE TORELLÓ', 'LLADURS', 'JAFRE',
#        "CANET D'ADRI", 'CASTELLAR DE LA RIBERA', 'SANT MARTÍ DE LLÉMENA',
#        'VILADASENS', 'ULLÀ', "BELLCAIRE D'EMPORDÀ",
#        'SANT AGUSTÍ DE LLUÇANÈS', 'GUIMERÀ', 'CAMÓS',
#        'VALLFOGONA DE RIUCORB', 'OLVAN', 'SANT RAMON', 'ORÍS', 'AVIÀ',
#        'CERVIÀ DE TER', 'TORNABOUS', 'FOIXÀ', 'TORELLÓ', 'BORDILS',
#        'FLAÇÀ', 'SUSQUEDA', 'CAMARASA', 'MONTCLAR', 'SANT JOAN DE MOLLET',
#        'SANTA MARIA DE MERLÈS', 'LLIÇÀ DE VALL', 'CASSERRES', 'ULTRAMORT',
#        'SERRA DE DARÓ', 'FONTANILLES', 'CELRÀ', 'GIRONELLA',
#        'SANT MARTÍ VELL', 'GUALTA', 'TAVERTET', 'OLOST', 'XERTA', 'RUPIÀ',
#        'ULLASTRET', 'VERGES', 'MARTORELLES', 'SANT VICENÇ DE TORELLÓ',
#        'SANT BOI DE LLUÇANÈS', 'PERAFITA', 'SAGÀS', 'BOT', 'CAMBRILS',
#        'FREGINALS', 'BENISSANET', 'PRATDIP', 'MIRAVET', 'GINESTAR',
#        'HORTA DE SANT JOAN', 'RASQUERA', 'PRAT DE COMTE', 'PAÜLS',
#        'BAUSEN', 'BOADELLA I LES ESCAULES', 'CANEJAN', 'LES', 'NAUT ARAN',
#        "VILANOVA D'ESCORNALBOU", 'GUARDIOLA DE BERGUEDÀ', 'BOSSÒST',
#        'MONTBRIÓ DEL CAMP', 'VINYOLS I ELS ARCS', 'CISTELLA',
#        'GISCLARENY', 'SALES DE LLIERCA', 'CONCA DE DALT', 'VILABERTRAN',
#        'FIGUERES', 'OGASSA', 'MARÇÀ', 'MÓRA LA NOVA', "MÓRA D'EBRE",
#        'VILA-SACRA', 'MASDENVERGE', 'CAPÇANES', 'COLLDEJOU',
#        'ALFARA DE CARLES', 'BARBERÀ DE LA CONCA', 'ALDOVER', 'TORTOSA',
#        'SANT MIQUEL DE FLUVIÀ', 'CAMARLES', 'FORTIÀ',
#        'AVINYONET DE PUIGVENTÓS', 'SANTA BÀRBARA', "SANT JAUME D'ENVEJA",
#        'GODALL', 'SANT MORI', 'MOLLET DE PERALADA', 'MASARAC', 'BIURE',
#        'VILAJUÏGA', 'TERRADES', 'PARDINES', 'PONT DE MOLINS',
#        'PEDRET I MARZÀ', 'CABANES', 'FÍGOLS I ALINYÀ', 'PAU', 'BAGÀ',
#        'MONTFERRER I CASTELLBÒ', 'PALAU-SAVERDERA', 'LLADÓ', 'VILAFANT',
#        'LLERS', 'VILAMALLA', "CASTELLAR DE N'HUG", 'CAMPELLES',
#        'BORRASSÀ', 'SANT PAU DE SEGÚRIES', "CASTELLÓ D'EMPÚRIES",
#        'SALDES', 'SALÀS DE PALLARS', 'CAMPDEVÀNOL', 'SIURANA',
#        'SANT JAUME DE FRONTANYÀ', 'CASTELLFOLLIT DE LA ROCA', 'RIUDAURA',
#        'VILAMACOLUM', 'TORROELLA DE FLUVIÀ', 'GARRIGÀS', 'ALBINYANA',
#        'VALLFOGONA DE RIPOLLÈS', 'CRESPIÀ', 'ISÒVOL', 'BESALÚ', 'ALIÓ',
#        "CASTELL DE L'ARENY", 'MASLLORENÇ', 'PONTÓS', 'OLOT', 'CABANELLES',
#        'CERCS', 'PALAU DE SANTA EULÀLIA', 'MERANGES', 'FÍGOLS', 'SERINYÀ',
#        'ARRES', 'VENTALLÓ', 'VIDRÀ', 'SANT MIQUEL DE CAMPMAJOR',
#        'LLADORRE', 'ALINS', 'VILADA', 'ESPOT', 'LLORENÇ DEL PENEDÈS',
#        'VILAMÒS', "ESTERRI D'ÀNEU", 'ESTERRI DE CARDÓS', 'TÍRVIA',
#        'LLÍVIA', 'CANTALLOPS', 'GUILS DE CERDANYA', 'GER', 'ESPOLLA',
#        'PUIGCERDÀ', 'RODONYÀ', 'BÀSCARA', 'OLIANA', 'TORTELLÀ', 'BRÀFIM',
#        'ORGANYÀ', 'VALLCEBRE', 'ABELLA DE LA CONCA',
#        'SANT JULIÀ DE CERDANYOLA', "SANTA LLOGAIA D'ÀLGUEMA",
#        'MAIÀ DE MONTCAL', 'COLL DE NARGÓ', 'ORDIS', 'SANT JOAN LES FONTS',
#        'TALARN', 'SANT JAUME DE LLIERCA', 'SANT FERRIOL', 'ARGELAGUER',
#        'NULLES', 'FONTANALS DE CERDANYA', 'ALELLA', 'MOLLÓ',
#        'SANTA OLIVA', 'DAS', 'BOLVIR', 'CAPMANY',
#        'SANT MARTÍ SESGUEIOLES', 'VILALLONGA DE TER', 'VILABELLA',
#        'SANT CLIMENT SESCEBES', 'BAIX PALLARS', 'ARBOLÍ', 'SETCASES',
#        'PRATS I SANSOR', 'AGULLANA', 'PRULLANS', 'ARSÈGUEL', 'QUERALBS',
#        'ESTAMARIU', 'VILAMANISCLE', 'ALP', 'LLANARS', 'RIUDECOLS', 'CAVA',
#        'PERAFORT', 'BOTARELL', 'POBOLEDA', 'CONSTANTÍ', 'REUS',
#        'DUESAIGÜES', 'CUBELLES', 'PRADELL DE LA TEIXETA',
#        'BELLMUNT DEL PRIORAT', 'MONTELLÀ I MARTINET', 'GARRIGUELLA',
#        'ALÀS I CERC', 'TOSES', 'PLANOLES', 'SENTERADA', 'VILAGRASSA',
#        'URÚS', 'VINEBRE', 'BONASTRE', 'ALFORJA', 'RENAU',
#        'VILALLONGA DEL CAMP', 'ASCÓ', 'PORRERA', 'PIRA',
#        'GRANYENA DE LES GARRIGUES', 'ALMOSTER', 'TORREBESSES', 'CREIXELL',
#        'CASTELLOLÍ', 'CASTELLVELL DEL CAMP', 'MASPUJOLS', 'DOSRIUS',
#        'MONISTROL DE MONTSERRAT', 'SANT POL DE MAR',
#        'TORRELLES DE LLOBREGAT', 'MONTORNÈS DE SEGARRA', 'PUIGPELAT',
#        'VILANOVA DE PRADES', 'TIANA', 'SANT CUGAT SESGARRIGUES',
#        'CORNELLÀ DE LLOBREGAT', 'CASTELLVÍ DE LA MARCA', 'BEGUES',
#        'PRADES', 'ROSSELLÓ', 'OLÈRDOLA', 'BOVERA',
#        'SANT BOI DE LLOBREGAT', "RIBA-ROJA D'EBRE", 'PRATS DE LLUÇANÈS',
#        'SANT CLIMENT DE LLOBREGAT', 'VALLS', 'SANT JAUME DELS DOMENYS',
#        'MARGALEF', 'SANTA MARGARIDA I ELS MONJOS', 'VILA-RODONA',
#        'CAPAFONTS', 'CORNUDELLA DE MONTSANT', 'MONT-RAL', 'VILADECANS',
#        'OLIVELLA', 'BELLVEI', 'RIUDOMS', 'ALTAFULLA',
#        'TORROJA DEL PRIORAT', 'VILASSAR DE MAR', 'SALOMÓ', 'COLLBATÓ',
#        'VILAPLANA', 'PREMIÀ DE MAR', 'FULLEDA', 'BADALONA',
#        'CASTELLET I LA GORNAL', 'HOSTALRIC', 'CANYELLES', 'CASTELLDEFELS',
#        'BANYERES DEL PENEDÈS', 'SANT PERE DE RIBES', 'CABACÉS',
#        'MOLLERUSSA', 'VALLMOLL', 'MIRALCAMP', 'MONTOLIU DE SEGARRA',
#        'MONTFERRI', 'TORREGROSSA', 'CAMPINS', 'ROCAFORT DE QUERALT',
#        'GIMENELLS I EL PLA DE LA FONT', 'MARTORELL', 'TORDERA', 'CORBINS',
#        'GRANOLLERS', 'TORRES DE SEGRE', 'BADIA DEL VALLÈS', 'MEDIONA',
#        'TEIÀ', 'SENAN', 'ALCANÓ', 'MASSALCOREIG', 'CERDANYOLA DEL VALLÈS',
#        'RIPOLLET', "SANT LLORENÇ D'HORTONS", 'NAVÀS',
#        'SANT JULIÀ DE VILATORTA', 'PALAU-SOLITÀ I PLEGAMANS',
#        'SANTA EULÀLIA DE RIUPRIMER', 'IVARS DE NOGUERA', 'BLANCAFORT',
#        'FORADADA', 'AIGUAVIVA', "VILOBÍ D'ONYAR",
#        'SANTA EUGÈNIA DE BERGA', 'PINÓS', 'PALAFRUGELL',
#        "SANTA MARIA D'OLÓ", 'TORÀ', 'SANT CELONI', 'CAMPLLONG',
#        'BENAVENT DE SEGRIÀ', 'IGUALADA', 'CALLDETENES',
#        'SANT MARTÍ DE RIUCORB', 'SOLIVELLA', "SANT SADURNÍ D'OSORMORT",
#        'SANT VICENÇ DE MONTALT', 'SUDANELL', 'JUNEDA', 'ARTESA DE LLEIDA',
#        'FIGARÓ-MONTMANY', 'ARENYS DE MAR', 'BELIANES',
#        'SANT ESTEVE DE PALAUTORDERA', 'SOSES', 'VILANOVA DE LA BARCA',
#        'CANET DE MAR', 'BELLVÍS', 'SANTA MARGARIDA DE MONTBUI',
#        'CASTELLFOLLIT DEL BOIX', 'TORRE-SERONA', 'SANT ANDREU SALOU',
#        'ALPICAT', 'BARBENS', 'SANT FELIU DE CODINES', 'ARGENTONA',
#        'SANT LLORENÇ SAVALL', 'GALLIFA', 'SANT SALVADOR DE GUARDIOLA',
#        'BIGUES I RIELLS', 'TORREFARRERA', 'RIUDELLOTS DE LA SELVA',
#        'SANTA COLOMA DE FARNERS', 'SANTA MARIA DE PALAUTORDERA', 'MALLA',
#        'SANAÜJA', "SANTA CRISTINA D'ARO", 'MONTOLIU DE LLEIDA',
#        'CASSÀ DE LA SELVA', 'ALGERRI', 'PUIGGRÒS', 'BALSARENY',
#        'ESPINELVES', 'CUBELLS', 'CABANABONA', 'CALDES DE MALAVELLA',
#        'CASTELLNOU DE BAGES', 'ALBATÀRREC', 'MONTGAT',
#        'SANTA COLOMA DE QUERALT', 'SANT ANDREU DE LA BARCA',
#        'SANT JOAN DESPÍ', 'VILANOVA DEL CAMÍ', 'VIMBODÍ I POBLET',
#        'ULLDEMOLINS', 'ANGLESOLA', 'SANT VICENÇ DELS HORTS', 'SILS',
#        'SÚRIA', 'COLLSUSPINA', 'PALAMÓS', 'MONTGAI',
#        'SANTA PERPÈTUA DE MOGODA', 'RIUDARENES', 'ALMENAR', 'BALAGUER',
#        'SANT QUINTÍ DE MEDIONA', 'BALENYÀ', 'MASSOTERES', 'MALDÀ',
#        'CASTELLDANS', 'SAVALLÀ DEL COMTAT', 'PARETS DEL VALLÈS', 'AITONA',
#        'VILADECAVALLS', 'LLORAC', 'OLESA DE MONTSERRAT',
#        'VILANOVA DEL VALLÈS', 'MOLLET DEL VALLÈS', 'ALFÉS',
#        'MONTORNÈS DEL VALLÈS', 'CAPELLADES', 'PONTONS',
#        'CORBERA DE LLOBREGAT', 'PALLEJÀ', 'CABRILS',
#        'SANT PERE DE RIUDEBITLLES', 'PREIXENS', 'JUNCOSA', 'VILA-SANA',
#        'FONT-RUBÍ', 'TORRELLES DE FOIX', 'MOLINS DE REI', 'ALFARRÀS',
#        'AGRAMUNT', 'CASTELLÓ DE FARFANYA', 'CASTELLGALÍ', 'TONA',
#        'GRANYANELLA', 'CIUTADILLA', 'NALEC', 'MONTMELÓ', 'ÒRRIUS',
#        'CABRA DEL CAMP', 'SANTA SUSANNA', 'VALLGORGUINA', 'COPONS',
#        'RELLINARS', 'CALLÚS', 'SANT GUIM DE FREIXENET',
#        'SANT FELIU DE BUIXALLEU', 'SANT VICENÇ DE CASTELLET', 'BELLPUIG',
#        'CARDEDEU', 'PALAFOLLS', "CALDES D'ESTRAC", 'CALDES DE MONTBUI',
#        'ALCARRÀS', 'POLINYÀ', 'ESPLUGUES DE LLOBREGAT', 'ARTÉS',
#        'VALLFOGONA DE BALAGUER', 'ALBESA', 'IVORRA', 'SANTPEDOR',
#        'CASTELLFOLLIT DE RIUBREGÓS', 'CENTELLES', 'GUISSONA', 'ALCOLETGE',
#        "PUIGVERD D'AGRAMUNT", 'FONOLLOSA', 'PASSANANT I BELLTALL',
#        "BELL-LLOC D'URGELL", 'SUNYER', 'FOGARS DE MONTCLÚS',
#        'SANT PERE SALLAVINERA', 'SANT FRUITÓS DE BAGES', 'ALGUAIRE',
#        'SANTA EULÀLIA DE RONÇANA', 'CASTELLTERÇOL',
#        'MONISTROL DE CALDERS', 'MENÀRGUENS', 'SANT ANTONI DE VILAMAJOR',
#        'LLINARS DEL VALLÈS', 'GOLMÉS', 'CASTELLAR DEL VALLÈS',
#        'MALGRAT DE MAR', 'SANT JUST DESVERN', 'MARGANELL', 'SENTMENAT',
#        'MATADEPERA', "VALLBONA D'ANOIA", 'CONESA',
#        'VALLBONA DE LES MONGES', 'VIDRERES', 'MASSANES', 'CALDERS',
#        'VALLIRANA', 'AIGUAFREDA', "BELLCAIRE D'URGELL", 'OSSÓ DE SIÓ',
#        'CALONGE DE SEGARRA', 'SANT JOAN DE VILATORRADA', 'CARME',
#        'CASTELLCIR', 'SANT GUIM DE LA PLANA', 'RIELLS I VIABREA',
#        'MAÇANET DE LA SELVA', 'SANT CEBRIÀ DE VALLALTA', 'SIDAMON',
#        'SANTA FE DEL PENEDÈS', 'SANTA COLOMA DE CERVELLÓ',
#        'FIGUEROLA DEL CAMP', 'BELLAGUARDA', 'OLESA DE BONESVALLS',
#        'SANT FELIU DE GUÍXOLS', 'VILALBA SASSERRA', 'ALMATRET',
#        'CASTELLSERÀ', 'SANT ADRIÀ DE BESÒS', 'PENELLES',
#        'SANT FELIU DE LLOBREGAT', 'SANT ISCLE DE VALLALTA',
#        'SANT MARTÍ SARROCA', 'CERVELLÓ', 'MAIALS', 'AIGUAMÚRCIA',
#        'PUIGDÀLBER', 'ORPÍ', 'VALLCLARA', 'VECIANA', 'ARGENÇOLA',
#        'NAVARCLES', 'JORBA', 'ARENYS DE MUNT', 'BELLPRAT',
#        'AGUILAR DE SEGARRA', 'TÉRMENS', 'GUALBA', 'BREDA',
#        'SANT QUIRZE SAFAJA', 'MANRESA', 'LINYOLA', 'TÀRREGA',
#        'TARROJA DE SEGARRA', 'ESTARÀS', 'PINEDA DE MAR',
#        'VILANOVA DE BELLPUIG', 'ULLASTRELL', 'CABRERA DE MAR', 'ABRERA',
#        'ASPA', 'LLARDECANS', 'BARBERÀ DEL VALLÈS', 'TORRENT', 'TARRÉS',
#        'PREIXANA', 'VILABLAREIX', 'PONTS', 'GRANERA', 'TORRELAMEU',
#        'VILANOVA DE SEGRIÀ', 'CERVERA', 'FOGARS DE LA SELVA', 'PUJALT',
#        'FORÈS', 'VILASSAR DE DALT', 'FOLGUEROLES', 'VALLROMANES',
#        'REGENCÓS', 'SANT QUIRZE DEL VALLÈS', 'SANTA COLOMA DE GRAMENET',
#        'TORRELAVIT', "SANT SADURNÍ D'ANOIA", 'FORNELLS DE LA SELVA',
#        'GELIDA', 'CÀNOVES I SAMALÚS', 'CASTELLVÍ DE ROSANES', 'CALAF',
#        'CANOVELLES', 'SANT PERE DE VILAMAJOR', 'RAJADELL',
#        'SANTA MARIA DE MARTORELLES', 'PONTILS', 'CALELLA', 'VERDÚ',
#        "LLIÇÀ D'AMUNT", 'VILAFRANCA DEL PENEDÈS',
#        'SANT FOST DE CAMPSENTELLES', 'RIUDECANYES', 'SARROCA DE LLEIDA',
#        'CASTELLBISBAL', 'PREMIÀ DE DALT'], dtype=object)

# %%
#df['Sex'].replace('D', 'F') #replace method
#df['Sex'].replace({'D': 'F', 'N': 'M'})
#df.replace({
#    'Sex': {
 #       'D': 'F',
 #       'N': 'M'
 #   },
  #  'Age': {
   #     290: 29
    #}
#})

# %%
df[df['Taxa_vacunacio'] > 200] # semblanta dades covis
# Out:
# Empty GeoDataFrame
# Columns: [codi_ine_6, provincia1, codi_costa, codi_ptgc_, comarca1, id, nom_muni, municipi, codi_cadas, codi_aft, _feature_id, codi_ptgc, cap_muni, codiine, geometry, Total, Municipi, Taxa_vacunacio]
# Index: []

# %% [markdown]
# ## Duplicates

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 809    False
# 810    False
# 811    False
# 812    False
# 813    False
# Length: 814, dtype: bool

# %%
df.duplicated(subset=['Municipi'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 809    False
# 810    False
# 811    False
# 812    False
# 813    False
# Length: 814, dtype: bool

# %%
#players.duplicated(subset=['Name'], keep='last')
#players.drop_duplicates()
