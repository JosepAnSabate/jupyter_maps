# %%
import folium
import geopandas as gpd
import pandas as pd
import json
import random
import requests
import os
import numpy as np
import geoplot as gplt
from branca.colormap import linear
import plotly.express as px

# %%
import plotly.io as pio  
pio.renderers.default = 'browser' #map in the browser

# %% [markdown]
# # Import data

# %%
vac_csv = f"C:/Users/34639/wa/jupyter/dades_covid/vacu_espat.csv"
df = gpd.read_file(vac_csv, sep=',')
df.head(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b8f622f93fd1> in <module>
#       1 vac_csv = f"C:/Users/34639/wa/jupyter/dades_covid/vacu_espat.csv"
# ----> 2 df = gpd.read_file(vac_csv, sep=',')
#       3 df.head(3)
#
# NameError: name 'gpd' is not defined

# %%
print(df.dtypes)

# %%
df = gpd.GeoDataFrame(df, geometry='geometry')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-132-1440f8d06063> in <module>
# ----> 1 df = gpd.GeoDataFrame(df, geometry='geometry')
#
# ~\anaconda3\envs\geo_env\lib\site-packages\geopandas\geodataframe.py in __init__(self, geometry, crs, *args, **kwargs)
#     165                 )
#     166                 # TODO: raise error in 0.9 or 0.10.
# --> 167             self.set_geometry(geometry, inplace=True)
#     168
#     169         if geometry is None and crs:
#
# ~\anaconda3\envs\geo_env\lib\site-packages\geopandas\geodataframe.py in set_geometry(self, col, drop, inplace, crs)
#     293
#     294         # Check that we are using a listlike of geometries
# --> 295         level = _ensure_geometry(level, crs=crs)
#     296         index = frame.index
#     297         frame[geo_column_name] = level
#
# ~\anaconda3\envs\geo_env\lib\site-packages\geopandas\geodataframe.py in _ensure_geometry(data, crs)
#      41             return GeoSeries(out, index=data.index, name=data.name)
#      42         else:
# ---> 43             out = from_shapely(data, crs=crs)
#      44             return out
#      45
#
# ~\anaconda3\envs\geo_env\lib\site-packages\geopandas\array.py in from_shapely(data, crs)
#     166
#     167     """
# --> 168     return GeometryArray(vectorized.from_shapely(data), crs=crs)
#     169
#     170
#
# ~\anaconda3\envs\geo_env\lib\site-packages\geopandas\_vectorized.py in from_shapely(data)
#     131             out.append(None)
#     132         else:
# --> 133             raise TypeError("Input must be valid geometry objects: {0}".format(geom))
#     134
#     135     if compat.USE_PYGEOS:
#
# TypeError: Input must be valid geometry objects: MULTIPOLYGON (((1.863408216214408 41.91647845329365, 1.860888469340134 41.92024145119075, 1.856931874131812 41.92573177492063, 1.854149345614427 41.93026646985486, 1.851371365105905 41.93422913391189, 1.850987684177773 41.9346385127928, 1.848271484565262 41.93759226624352, 1.855886105686176 41.93875226279516, 1.85699164179732 41.93932186108803, 1.858552973802147 41.94039061998656, 1.858580309424843 41.94058282057638, 1.858917835649278 41.94087420479586, 1.858989093009902 41.94098461247694, 1.859236420353156 41.94119295968984, 1.859148465876731 41.94132907452059, 1.858962859436621 41.94142783225032, 1.858735204148461 41.94150329505268, 1.857883455726589 41.94156795571327, 1.857571475079542 41.94154197438085, 1.857259202529744 41.94155264578554, 1.856711615690245 41.94171624487608, 1.856362998867071 41.94187056587469, 1.855996661548395 41.94199030432673, 1.85579731834547 41.94201353551881, 1.855600171065356 41.94209614113893, 1.8552344783814 41.94234836927824, 1.854994765558437 41.94263220496966, 1.855126843201282 41.94276150491605, 1.855258048560329 41.94313532262823, 1.85518127662757 41.94348202846277, 1.85504972364382 41.94383602426446, 1.854934502181162 41.94394457448583, 1.854574710996824 41.94403474258587, 1.854139509006981 41.94406480363493, 1.853533344614415 41.94425743476732, 1.853414200945213 41.94442313579994, 1.853389786384254 41.94458059640293, 1.853487840509913 41.94473702876603, 1.854578503225568 41.9451849154479, 1.854673050722206 41.94538247166687, 1.854411589428589 41.94584261822352, 1.854237278972726 41.94601011113555, 1.853488165560521 41.94630200796374, 1.853248184509836 41.94637724688526, 1.852593443558318 41.94649877638616, 1.851983720915447 41.94653843269811, 1.851518761398465 41.94653152954827, 1.851353797200781 41.94652051197482, 1.850713700096732 41.94637711494634, 1.850336784797973 41.94640531341306, 1.850083979428547 41.9465494973903, 1.850032989758239 41.94700381656885, 1.850051711564156 41.94715036033596, 1.85011325194558 41.94731093294549, 1.850220757348104 41.9474514310818, 1.850341302068815 41.94755783489235, 1.850529237550263 41.94766707506621, 1.850754136482363 41.9477402085826, 1.85138459249619 41.94786360443615, 1.852199516455451 41.94816888229993, 1.852232024688473 41.94823315377181, 1.852218040097721 41.94832677193666, 1.851923640833039 41.94853638172426, 1.851668398650728 41.94876232407901, 1.850752553358839 41.94942108192867, 1.850044123544206 41.94982936755993, 1.849788085623226 41.95010564421208, 1.84959280922133 41.95042467986506, 1.849473702128527 41.95075492628772, 1.849635759858958 41.95093496998198, 1.849819424088783 41.95108766998435, 1.849882118606198 41.95117746286267, 1.850155262452152 41.95131259552792, 1.850339482706296 41.95146133738681, 1.850396070423118 41.95154188215173, 1.850445723582367 41.95167936875696, 1.85044602885324 41.95183032122144, 1.850308247040177 41.95199123880992, 1.850231701782093 41.95216195633291, 1.850046346381113 41.95243894148255, 1.84981591247492 41.95269980323992, 1.849451358969405 41.95289735526119, 1.849257274467312 41.95296160752314, 1.849048234936265 41.95300535474398, 1.84883245755712 41.95300778411752, 1.848612549633032 41.95298495337728, 1.848411309732694 41.95293718131085, 1.848055242440161 41.95285732296939, 1.847684329363376 41.95280460425217, 1.846973053390811 41.95281178150668, 1.846683508284609 41.95290389128291, 1.846254712018964 41.95343177739831, 1.846169155561231 41.9536264490062, 1.845994578337372 41.95394685726899, 1.845818937024945 41.95425257391411, 1.845487897696842 41.95472478899625, 1.845421455613884 41.95492982963862, 1.845421777046392 41.95534674479867, 1.845513559405543 41.95548276586067, 1.84571709111826 41.95553759112503, 1.846220519072467 41.95554265286435, 1.847060254707814 41.95563341072069, 1.847208866829388 41.95567597317793, 1.847411237864681 41.95579536053928, 1.84770539428686 41.95605094700024, 1.8477975155681 41.95617517108146, 1.847822104434649 41.95655864537477 ...

# %%
import matplotlib.pyplot as plt
import geoplot as gplt

# %%
# Initialize the figure
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 1, figsize=(16, 12))

# Set up the color sheme:
import mapclassify as mc
scheme = mc.Quantiles(fullData['Taxa_vacunacio'], k=10)

# Map
gplt.choropleth(fullData, 
    hue="Taxa_vacunacio", 
    linewidth=.1,
    scheme=scheme, cmap='inferno_r',
    legend=True,
    edgecolor='black',
    ax=ax
);

ax.set_title('Número de vacunes administrades oer cada 100 habitants', fontsize=13);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-128-33896fefbf07> in <module>
#       5 # Set up the color sheme:
#       6 import mapclassify as mc
# ----> 7 scheme = mc.Quantiles(fullData['Taxa_vacunacio'], k=10)
#       8
#       9 # Map
#
# NameError: name 'fullData' is not defined
