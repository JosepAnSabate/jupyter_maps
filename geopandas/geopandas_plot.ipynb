# %%
# %matplotlib inline
import pandas as pd
import geopandas as gpd

# %%
world = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))#example gpd datasets

# %%
world
# Out:
#        pop_est      continent                      name iso_a3  gdp_md_est  \
# 0       920938        Oceania                      Fiji    FJI      8374.0
# 1     53950935         Africa                  Tanzania    TZA    150600.0
# 2       603253         Africa                 W. Sahara    ESH       906.5
# 3     35623680  North America                    Canada    CAN   1674000.0
# 4    326625791  North America  United States of America    USA  18560000.0
# ..         ...            ...                       ...    ...         ...
# 172    7111024         Europe                    Serbia    SRB    101800.0
# 173     642550         Europe                Montenegro    MNE     10610.0
# 174    1895250         Europe                    Kosovo    -99     18490.0
# 175    1218208  North America       Trinidad and Tobago    TTO     43570.0
# 176   13026129         Africa                  S. Sudan    SSD     20880.0
#
#                                               geometry
# ...

# %%
world.plot()
# Out:
# <AxesSubplot:>

# %%
af=world.loc[world["continent"] == "Africa"]

# %%
af.plot(column="pop_est")
# Out:
# <AxesSubplot:>

# %%
af.plot(column="pop_est", cmap="terrain", figsize=(10,10))
# https://matplotlib.org/stable/tutorials/colors/colormaps.html
# Out:
# <AxesSubplot:>

# %%
na=world.loc[world["continent"] == "North America"]
na.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # CRS

# %%
na.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
#change crs
na = na.to_crs("EPSG:3310")

# %%
na.plot()
# Out:
# <AxesSubplot:>
